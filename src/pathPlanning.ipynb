# %%
from robots_moviles.topology_library import PathPlanner, GraphIO

# %%
MAP_NUMBER = '1'# Modificar !!!
GRAFO_FILE = f"results/topologico/optimized/grafo_optimizado_{MAP_NUMBER}.json.gz"
RESULT_DIR = f"results/topologico/optimized"

# %%
graph_io = GraphIO()
loaded_graph = graph_io.load_graph(GRAFO_FILE)
# loaded_graph = graph_io.load_graph_pickle(GRAFO_FILE)

# %%
# Crear el planificador
planner = PathPlanner(loaded_graph)

# Usar normalmente
path_info = planner.get_detailed_path('R2_N33', 'R3_N5')#mapa 1
# path_info = planner.get_detailed_path('R4_N49', 'R9_N106')#mapa 2
# path_info = planner.get_detailed_path('R4_N126', 'D11')#mapa 3
# path_info = planner.get_detailed_path('R2_N', 'D2')#mapa 4
planner.visualize_path(path_info,path=f"{RESULT_DIR}/path_grafo_optimized_escenario_{MAP_NUMBER}.png")
